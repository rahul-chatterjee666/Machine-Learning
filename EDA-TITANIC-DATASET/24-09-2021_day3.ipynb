# %%
import pandas as pd
file =pd.read_csv("titanic.csv")
file
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_copy=file.transpose()
titanic_copy
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
import pandas as pd

# %%
from datetime import datetime

# %%
import numpy as np

# %%
# Let's create a pandas series that logs time every hour from 1st Nov'19 to 7th Nov'19

# %% [markdown]
# # doubt to me???

# %%
# df=pd.date_range(start='01/01/2021',end='01/12/2021',freq="H")   ?????????????
df = pd.date_range(start='11/01/2019', end='11/07/2019', freq='H')

# %%
df
# Out:
# DatetimeIndex(['2019-11-01 00:00:00', '2019-11-01 01:00:00',
#                '2019-11-01 02:00:00', '2019-11-01 03:00:00',
#                '2019-11-01 04:00:00', '2019-11-01 05:00:00',
#                '2019-11-01 06:00:00', '2019-11-01 07:00:00',
#                '2019-11-01 08:00:00', '2019-11-01 09:00:00',
#                ...
#                '2019-11-06 15:00:00', '2019-11-06 16:00:00',
#                '2019-11-06 17:00:00', '2019-11-06 18:00:00',
#                '2019-11-06 19:00:00', '2019-11-06 20:00:00',
#                '2019-11-06 21:00:00', '2019-11-06 22:00:00',
#                '2019-11-06 23:00:00', '2019-11-07 00:00:00'],
#               dtype='datetime64[ns]', length=145, freq='H')

# %% [markdown]
# **NOTE ISO 8601 format**
# -  yyyy-mm-dd hh:mm:ss
# -  2021-01-01 00:00:0

# %%
len(df)
# Out:
# 145

# %%
type(df)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ???? what is (pandas.core.indexes.datetimes.DatetimeIndex) vs pandas.core.Series

# %%
# turning the (pandas.core.indexes.datetimes.DatetimeIndex) into dataFrame
# df=pd.DataFrame(index="df",columns=["date"])
df = pd.DataFrame(df, columns=['date'])
df["sales"]=np.random.randint(1,1000,size=(len(df)))

# %%
df.head()
# Out:
#                  date  sales
# 0 2019-11-01 00:00:00    716
# 1 2019-11-01 01:00:00    137
# 2 2019-11-01 02:00:00    505
# 3 2019-11-01 03:00:00     90
# 4 2019-11-01 04:00:00    463

# %%
file
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.set_index('date')

# %%
df
# Out:
#                      sales
# date
# 2019-11-01 00:00:00    716
# 2019-11-01 01:00:00    137
# 2019-11-01 02:00:00    505
# 2019-11-01 03:00:00     90
# 2019-11-01 04:00:00    463
# ...                    ...
# 2019-11-06 20:00:00    251
# 2019-11-06 21:00:00    160
# 2019-11-06 22:00:00     39
# 2019-11-06 23:00:00    665
# 2019-11-07 00:00:00    826
#
# [145 rows x 1 columns]

# %%
df.loc['2019-11-01 00:00:00','sales']
# Out:
# 716

# %%
df.loc['2019-11-01 00:00:00']
# Out:
# sales    716
# Name: 2019-11-01 00:00:00, dtype: int32

# %%
df.loc['2019-11-01']
# Out:
#                      sales
# date
# 2019-11-01 00:00:00    716
# 2019-11-01 01:00:00    137
# 2019-11-01 02:00:00    505
# 2019-11-01 03:00:00     90
# 2019-11-01 04:00:00    463
# 2019-11-01 05:00:00    951
# 2019-11-01 06:00:00    929
# 2019-11-01 07:00:00    156
# 2019-11-01 08:00:00    690
# 2019-11-01 09:00:00    842
# 2019-11-01 10:00:00    408
# 2019-11-01 11:00:00    109
# 2019-11-01 12:00:00    145
# 2019-11-01 13:00:00    592
# 2019-11-01 14:00:00    271
# 2019-11-01 15:00:00    959
# 2019-11-01 16:00:00    301
# 2019-11-01 17:00:00     76
# 2019-11-01 18:00:00    424
# 2019-11-01 19:00:00    817
# 2019-11-01 20:00:00    160
# 2019-11-01 21:00:00    648
# 2019-11-01 22:00:00    652
# 2019-11-01 23:00:00    129

# %%
df.loc['2019-11']
# Out:
#                      sales
# date
# 2019-11-01 00:00:00    716
# 2019-11-01 01:00:00    137
# 2019-11-01 02:00:00    505
# 2019-11-01 03:00:00     90
# 2019-11-01 04:00:00    463
# ...                    ...
# 2019-11-06 20:00:00    251
# 2019-11-06 21:00:00    160
# 2019-11-06 22:00:00     39
# 2019-11-06 23:00:00    665
# 2019-11-07 00:00:00    826
#
# [145 rows x 1 columns]

# %%
df.loc['2019']
# Out:
#                      sales
# date
# 2019-11-01 00:00:00    716
# 2019-11-01 01:00:00    137
# 2019-11-01 02:00:00    505
# 2019-11-01 03:00:00     90
# 2019-11-01 04:00:00    463
# ...                    ...
# 2019-11-06 20:00:00    251
# 2019-11-06 21:00:00    160
# 2019-11-06 22:00:00     39
# 2019-11-06 23:00:00    665
# 2019-11-07 00:00:00    826
#
# [145 rows x 1 columns]

# %% [markdown]
# # Resampling
#
# **Summary States** - we can use Statistical methods over different time intervals
# - mean(), sum(), count(), min(), max()
#
# **Down-sampling**
# - reduce datetime rows to longer frequency
#
# **Up-sampling**
# - increase datetime rows to shorter frequency

# %%
# Using resample to get the average for each day per hour

df.resample('D').mean()
df.resample('D').sum()
# Out:
#             sales
# date
# 2019-11-01  11170
# 2019-11-02  12596
# 2019-11-03  10450
# 2019-11-04  10187
# 2019-11-05  11800
# 2019-11-06  10867
# 2019-11-07    826

# %% [markdown]
# ## Resampling frequencies
#
# - 'min', 'T' - minute
# - ‘H’ - hour
# - ‘D’ - day
# - ‘B’ - business day
# - ‘W’ - week
# - ‘M’ - month
# - ‘Q’ - quarter
# - ‘A’ - year

# %%
df = pd.DataFrame({'year': [2015, 2016],
                   'month': [2, 3],'day': [4, 5]})
df
# Out:
#    year  month  day
# 0  2015      2    4
# 1  2016      3    5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    2 non-null      int64
#  1   month   2 non-null      int64
#  2   day     2 non-null      int64
# dtypes: int64(3)
# memory usage: 176.0 bytes

# %%
pd.to_datetime(df)
# Out:
# 0   2015-02-04
# 1   2016-03-05
# dtype: datetime64[ns]

# %%
pd.to_datetime('20190101',format='%Y/%m/%d',errors='ignore')
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
pd.to_datetime('2019-01-01', format='%Y-%m-%d', errors='ignore')
# Out:
# Timestamp('2019-01-01 00:00:00')

# %% [markdown]
# # ??????

# %% [markdown]
# # day3 -Statistics

# %% [markdown]
# # types of statistic
# * descriptive statistics (A descriptive statistic is a summary statistic that quantitatively describes or summarizes features from a collection of information, while descriptive statistics is the process of using and analysing those statistics.)
# * inference(Statistical inference is the process of drawing conclusions about an underlying population based on a sample or subset of the data.)
# * risk and probability
# * correlation and relationship
# * modeling

# %% [markdown]
# # Statistics - Exploratory Data Analysis
#
# - Histogram plots
# - Scatter plots
# - Percentiles
# - Boxplots
# - Violin
# - Heatmaps
# - Barplots
# - Factor plots
# - Density plots
# - Joint Distribution plots

# %%
import pandas as pd
import numpy as np

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/winequalityN.csv"
df = pd.read_csv(file_name,encoding="ISO-8859-1")
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
x=df.groupby('type').agg(np.mean)

# %%
df["type"].unique()
# Out:
# array(['white', 'red'], dtype=object)

# %%
df.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df["quality"].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
df.count()
# Out:
# type                    6497
# fixed acidity           6487
# volatile acidity        6489
# citric acid             6494
# residual sugar          6495
# chlorides               6495
# free sulfur dioxide     6497
# total sulfur dioxide    6497
# density                 6497
# pH                      6488
# sulphates               6493
# alcohol                 6497
# quality                 6497
# dtype: int64

# %%
df.sum()
# Out:
# type                    whitewhitewhitewhitewhitewhitewhitewhitewhitew...
# fixed acidity                                                    46813.95
# volatile acidity                                                 2204.255
# citric acid                                                       2069.78
# residual sugar                                                    35360.9
# chlorides                                                          363.99
# free sulfur dioxide                                              198323.0
# total sulfur dioxide                                             751992.5
# density                                                        6462.54403
# pH                                                               20880.95
# sulphates                                                         3449.18
# alcohol                                                          68165.23
# quality                                                             37802
# ...

# %%
df.value_counts()
# Out:
# type   fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density   pH    sulphates  alcohol  quality
# white  7.0            0.15              0.28         14.7            0.051      29.0                 149.0                 0.997920  2.96  0.39       9.0      7          8
#        7.3            0.19              0.27         13.9            0.057      45.0                 155.0                 0.998070  2.94  0.41       8.8      8          8
#        7.4            0.16              0.30         13.7            0.056      33.0                 168.0                 0.998250  2.90  0.44       8.7      7          7
#        6.8            0.18              0.30         12.8            0.062      19.0                 171.0                 0.998080  3.00  0.52       9.0      7          7
# ...

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.hist(column='alcohol',bins=25)
# Out:
# array([[<AxesSubplot:title={'center':'alcohol'}>]], dtype=object)

# %%
df.hist(column="alcohol",bins=10,grid=False,figsize=(10,5),color='green') # grid=True will give grid_line or false=No!@!!
# figsize=(length,width)
# Out:
# array([[<AxesSubplot:title={'center':'alcohol'}>]], dtype=object)

# %% [markdown]
# # import seaborn

# %%
import seaborn as sns

# %%
sns.distplot(df['alcohol'],bins=25,kde=False,color='red')
# Out:
# c:\users\rahul.chatterjee\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol'>

# %%
sns.distplot(df['alcohol'],bins=25,kde=True,color='red')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
df["alcohol"].value_counts()
# Out:
# 9.500000     367
# 9.400000     332
# 9.200000     271
# 10.000000    229
# 10.500000    227
#             ...
# 10.533333      1
# 11.366667      1
# 12.333333      1
# 14.050000      1
# 10.750000      1
# Name: alcohol, Length: 111, dtype: int64

# %% [markdown]
# # Styling and Axis Labels
# * https://seaborn.pydata.org/tutorial/aesthetics.html?highlight=style

# %%
sns.distplot(df["alcohol"])
# Out:
# c:\users\rahul.chatterjee\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
sns.distplot(df.alcohol)

df['alcohol'] vs df.alcohol
# Out:
# c:\users\rahul.chatterjee\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # what is the difference between them ?????

# %%
import matplotlib.pyplot as plt

x=sns.distplot(df.alcohol,bins=15)
x=plt.xlabel('alcohol percentage')
x=plt.ylabel('count')
x=plt.title("Alcohol content")
x=plt.show()
x
# Out:
# c:\users\rahul.chatterjee\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style("dark")
sns.distplot(df.alcohol,bins=15,kde=True)
# Out:
# c:\users\rahul.chatterjee\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
sns.distplot(df.alcohol,bins=10,kde=False)
# Out:
# <AxesSubplot:xlabel='alcohol'>

# %% [markdown]
# # SCATTER PLOT

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
sns.lmplot(x='alcohol',y='fixed acidity',data=df,legend=True)

# %%
sns.lmplot(x='alcohol',y='density',data=df,legend=True,fit_reg=True)   # fit-reg is true means showing the trending line

# %%
sns.lmplot(x='alcohol',y='density',data=df,legend=True,fit_reg=False)  #fit-reg is False means not showing the trending line
